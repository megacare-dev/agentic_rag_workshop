# %% [markdown]
# # 📝 English Day 1: Data Engineering Pipeline
# ## Agentic RAG: From Zero to Hero
#
# ---
#
# ### 📋 English
#
# 1. **English** — English AI English
# 2. **English** — English **English** (English)
# 3. **English notebook English** English run English (.ipynb)
# 4. **English**: 10 English
#
# > ⚠️ **English** English hash, embedding, English score English

# %% [markdown]
# ## 📦 English Dependencies

# %%
# %%time
# !pip install -q sentence-transformers qdrant-client langchain-text-splitters rank_bm25 pythainlp scikit-learn

import hashlib, os, json, random, numpy as np, re
from sklearn.metrics.pairwise import cosine_similarity
print('✅ English!')

# %% [markdown]
# ## 🎓 English

# %%
# ─── English ───
STUDENT_NAME = ''   # English 'English English'
STUDENT_ID   = ''   # English '6512345678'
PHONE        = ''   # English '081-234-5678'
LINE_ID      = ''   # English 'somchai.j'

# ─── English (English) ───
assert len(STUDENT_ID) >= 5, '❌ English!'
assert len(STUDENT_NAME) >= 2, '❌ English-English!'

print(f'✅ English-English: {STUDENT_NAME}')
print(f'✅ English: {STUDENT_ID}')
print(f'📱 English: {PHONE}')
print(f'💬 LINE ID: {LINE_ID}')

# %% [markdown]
# ## 📄 Step 2: English (English cell English)

# %%
# %%time
# ===== English cell English =====
# English

random.seed(int(hashlib.md5(STUDENT_ID.encode()).hexdigest()[:8], 16))

# English — English
all_paragraphs = [
    'English English Machine Learning English English',
    'Deep Learning English Machine Learning English Neural Network English English English English English',
    'Natural Language Processing English NLP English English English English English English',
    'Retrieval Augmented Generation English RAG English LLM English English English',
    'Vector Database English Embedding Vector English',
    'Text Embedding English Vector English English',
    'Transformer English Neural Network English Attention English English GPT BERT English Gemini',
    'Prompt Engineering English Prompt English LLM English English Prompt English',
    'Fine-tuning English English English English',
    'Tokenization English Token English English English English',
    'Chunking English Embedding English Fixed-size Recursive English Semantic Chunking',
    'Cosine Similarity English Vector English Vector English 1 English English 0 English English NLP English Information Retrieval',
]

# English seed English
random.shuffle(all_paragraphs)

# English 8 English + English duplicate 1 English
selected = all_paragraphs[:8]
duplicate_idx = random.randint(0, 5)
selected.append(selected[duplicate_idx])  # English

# English
os.makedirs('homework_data', exist_ok=True)
for i, para in enumerate(selected):
    with open(f'homework_data/doc_{i+1}.txt', 'w', encoding='utf-8') as f:
        f.write(para)

print(f'✅ English {STUDENT_ID} English!')
print(f'📁 English: {len(selected)} English (English 1 English)')
for i in range(len(selected)):
    print(f'  📄 doc_{i+1}.txt ({len(selected[i])} English)')

# %% [markdown]
# ---
# ## 🎯 English: English Data Engineering Pipeline
#
# English **RAG Data Pipeline** English English
# English **English** — English
#
# ---
#
# ### English 1: English Duplicate English MD5 (2 English)
#
# - English MD5 hash English `homework_data/`
# - English
# - English (English)
#
# **📝 English:**
# 1. English?
# 2. MD5 hash English?
# 3. English?

# %%
# English 1: English duplicate English

# 💡 Hint:
#   1. import hashlib
#   2. English compute_md5(filepath) English return hash
#   3. English 'homework_data/' English hash English dict
#   4. English hash English → English duplicate



# ✅ Self-check (run English)
# assert dup_hash is not None, '❌ English duplicate'
# assert files_remaining >= 7, '❌ English 7'
# print(f'✅ Step 1 passed: English={dup_files}, MD5={dup_hash}')

# %% [markdown]
# ### English 2: Chunking (2 English)
#
# - English (English duplicate)
# - Chunk English `RecursiveCharacterTextSplitter` — English `chunk_size=150`, `chunk_overlap=30`
#
# **📝 English:**
# 1. English chunks?
# 2. Chunk English 1 English? (copy English)
# 3. Chunk English?

# %%
# English 2: English chunking English

# 💡 Hint:
#   1. from langchain_text_splitters import RecursiveCharacterTextSplitter
#   2. English
#   3. English splitter English chunk_size=150, chunk_overlap=30
#   4. English splitter.split_text(all_text)



# ✅ Self-check
# assert len(chunks) > 0, '❌ English chunk'
# assert len(chunks[0]) <= 150, '❌ chunk English'
# print(f'✅ Step 2 passed: {len(chunks)} chunks, chunk 1 = {len(chunks[0])} chars')

# %% [markdown]
# ### English 3: Embedding + Similarity (3 English)
#
# - English embedding English `intfloat/multilingual-e5-large`
# - English **Cosine Similarity** English query English chunk
# - Query: `'query: English'`
#
# **📝 English:**
# 1. Chunk English similarity English? (English chunk English score English 4 English)
# 2. Chunk English similarity English? (English chunk English score English 4 English)
# 3. English — English chunk English? (English 2-3 English)

# %%
# English 3: English embedding + similarity English
# English prefix 'query: ' English 'passage: ' English

# 💡 Hint:
#   1. from sentence_transformers import SentenceTransformer
#   2. model = SentenceTransformer('intfloat/multilingual-e5-large')
#   3. query = 'query: English'
#   4. passages = ['passage: ' + c for c in chunks]
#   5. query_emb = model.encode(query)
#   6. passage_embs = model.encode(passages)
#   7. English cosine_similarity() English sklearn



# ✅ Self-check
# assert best_score > 0.5, '❌ similarity score English English prefix'
# print(f'✅ Step 3 passed: best chunk={best_idx}, score={best_score:.4f}')

# %% [markdown]
# ### English 4: Qdrant Retrieval (3 English)
#
# - English Qdrant client (in-memory) + Collection English `f'hw_{STUDENT_ID}'`
# - Upsert English chunk + embedding English Qdrant
# - English query: `'query: English'`
# - English `top_k=3`
#
# **📝 English:**
# 1. English Top-3 English English score English? (English 4 English)
# 2. English 1 English?
# 3. English: English English? (English 3-5 English)

# %%
# English 4: English Qdrant retrieval English

# 💡 Hint:
#   1. from qdrant_client import QdrantClient, models
#   2. qdrant = QdrantClient(':memory:')
#   3. English collection English f'hw_{STUDENT_ID}'
#   4. Upsert English chunk + embedding English Qdrant
#   5. query = 'query: English'
#   6. qdrant.query_points(..., limit=3)



# ✅ Self-check
# assert len(results) == 3, '❌ English top_k=3 English'
# print(f'✅ Step 4 passed: Top-3 scores={[r.score for r in results]}')

# %% [markdown]
# ## 📊 English
#
# | English | English | English |
# |---------|:-----:|------|
# | 1. English Duplicates | 2 | English find_duplicates English, English |
# | 2. Chunking | 3 | chunk_size/overlap English, English |
# | 3. Embedding + Search | 3 | embed English, search English, English |
# | 4. English | 2 | English, English parameter |
# | **English** | **10** | |

# %% [markdown]
# ---
# ## ✅ English
#
# Run cell English **Verification Code** English

# %%
# ===== English cell English =====
verify_hash = hashlib.sha256(f'{STUDENT_ID}_day1_hw'.encode()).hexdigest()[:12]
print('=' * 50)
print(f'👤 English-English: {STUDENT_NAME}')
print(f'🎓 English: {STUDENT_ID}')
print(f'📱 English: {PHONE}')
print(f'💬 LINE ID: {LINE_ID}')
print(f'🔑 Verification Code: {verify_hash}')
print(f'📅 English: _________________ (English)')
print('=' * 50)
print()
print('📋 Checklist English:')
print('  [ ] English')
print('  [ ] English 1: English duplicate + MD5 hash')
print('  [ ] English 2: English chunks + English chunk English 1')
print('  [ ] English 3: English chunk English/English + English')
print('  [ ] English 4: English Top-3 scores + English')
print('  [ ] English cell run English')
